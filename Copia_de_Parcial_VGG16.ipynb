# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import numpy as np
import keras
import tensorflow as tf

# %%
model = VGG16()
# Out:
# ...
# 553467096/553467096 [==============================] - 8s 0us/step

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/2/24/Guitar_1.jpg
# Out:
# --2023-10-06 19:11:18--  https://upload.wikimedia.org/wikipedia/commons/2/24/Guitar_1.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 292923 (286K) [image/jpeg]
# Saving to: ‘Guitar_1.jpg’
#
# Guitar_1.jpg        100%[===================>] 286.06K  --.-KB/s    in 0.08s
#
# 2023-10-06 19:11:18 (3.61 MB/s) - ‘Guitar_1.jpg’ saved [292923/292923]

# %% [markdown]
# #Parte de Ejemplo Guitarra

# %%
img = keras.utils.load_img("/content/Guitar_1.jpg",
                                       target_size=(224, 224),
                                       keep_aspect_ratio=True)

# %%
img2 = keras.utils.img_to_array(img)

# %%
img3 = img2.reshape(1, 224, 224, 3)

# %%
img4 = preprocess_input(img3)

# %%
preprocess_input(img3).min()
# Out:
# -242.36

# %%
np.argmax(model.predict(img4))
# Out:
# 1/1 [==============================] - 9s 9s/step
# 402

# %%
np.max(model.predict(img4))
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 0.9981401

# %%
decode_predictions(model.predict(img4), top=5)
# Out:
# ...
# 35363/35363 [==============================] - 0s 0us/step
# [[('n02676566', 'acoustic_guitar', 0.9981401),
#   ('n03272010', 'electric_guitar', 0.0008767843),
#   ('n02787622', 'banjo', 0.00086913025),
#   ('n03929660', 'pick', 8.65124e-05),
#   ('n04536866', 'violin', 1.5313923e-05)]]

# %%
layer_1 = model.layers[1]

# %%
layer_1.weights[0][0][:, :, 0].shape
# Out:
# TensorShape([3, 3])

# %%
plt.imshow(layer_1.convolution_op(inputs=img3, kernel=layer_1.get_weights()[0])[0][:, :, 0])

# %% [markdown]
# #Imagenes propias (Balon)

# %%
img = keras.utils.load_img("/balon2.jpg",
                                       target_size=(224, 224),
                                       keep_aspect_ratio=True)

# %%
img2 = keras.utils.img_to_array(img)

# %%
img3 = img2.reshape(1, 224, 224, 3)

# %%
img4 = preprocess_input(img3)

# %%
preprocess_input(img3).min()
# Out:
# -247.36

# %%
np.argmax(model.predict(img4))
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 805

# %%
np.max(model.predict(img4))
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 0.99999976

# %%
decode_predictions(model.predict(img4), top=5)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [[('n04254680', 'soccer_ball', 0.99999976),
#   ('n04540053', 'volleyball', 2.7734924e-07),
#   ('n02790996', 'barbell', 8.548769e-09),
#   ('n04579432', 'whistle', 2.5750768e-10),
#   ('n03255030', 'dumbbell', 1.6911876e-10)]]

# %% [markdown]
# #Imagenes propias (Jordan)

# %%
img = keras.utils.load_img("/jordan2.jpg",
                                       target_size=(224, 224),
                                       keep_aspect_ratio=True)

# %%
img2 = keras.utils.img_to_array(img)

# %%
img3 = img2.reshape(1, 224, 224, 3)

# %%
img4 = preprocess_input(img3)

# %%
preprocess_input(img3).min()
# Out:
# -244.36

# %%
np.argmax(model.predict(img4))
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 770

# %%
np.max(model.predict(img4))
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 0.71647805

# %%
decode_predictions(model.predict(img4), top=5)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# [[('n04120489', 'running_shoe', 0.71647805),
#   ('n04019541', 'puck', 0.0756705),
#   ('n04228054', 'ski', 0.06383762),
#   ('n04133789', 'sandal', 0.04345209),
#   ('n04252077', 'snowmobile', 0.015350571)]]

# %% [markdown]
# #Imagenes propias (Gojo)

# %%
img = keras.utils.load_img("/perro.jpg",
                                       target_size=(224, 224),
                                       keep_aspect_ratio=True)

# %%
img2 = keras.utils.img_to_array(img)

# %%
img3 = img2.reshape(1, 224, 224, 3)

# %%
img4 = preprocess_input(img3)

# %%
preprocess_input(img3).min()
# Out:
# -241.36

# %%
np.argmax(model.predict(img4))
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 268

# %%
np.max(model.predict(img4))
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 0.99999475

# %%
decode_predictions(model.predict(img4), top=5)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [[('n02113978', 'Mexican_hairless', 0.99999475),
#   ('n02091032', 'Italian_greyhound', 4.8329634e-06),
#   ('n02087046', 'toy_terrier', 1.2778378e-07),
#   ('n02085620', 'Chihuahua', 1.2493133e-07),
#   ('n02091134', 'whippet', 6.584197e-08)]]

# %% [markdown]
# #Punto 1

# %%
img = '/content/Guitar_1.jpg'
img = tf.keras.preprocessing.image.load_img(img, target_size=(224, 224))
x = tf.keras.preprocessing.image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

capa = 'block1_conv2'
layer = model.get_layer(capa)

partial_model = tf.keras.Model(inputs=model.input, outputs=layer.output)

activations = partial_model.predict(x)

fig, axes = plt.subplots(8, 8, figsize=(10, 10))
for i in range(64):
    row = i // 8
    col = i % 8
    ax = axes[row, col]
    ax.imshow(activations[0, :, :, i], cmap='viridis')
    ax.axis('off')

plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8f11b831c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 86ms/step

# %% [markdown]
# #Punto 2

# %%
img = '/content/Guitar_1.jpg'
img = tf.keras.preprocessing.image.load_img(img, target_size=(224, 224))
x = tf.keras.preprocessing.image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

capa = 'block1_conv2'
layer = model.get_layer(capa)

partial_model = tf.keras.Model(inputs=model.input, outputs=layer.output)

activations = partial_model.predict(x)

output = partial_model.predict(x)

plt.imshow(output[0, :, :, 0], cmap='viridis')
plt.axis('off')
plt.title(f'Resultado de la capa {capa}')
plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 30ms/step

# %% [markdown]
# #Punto 3

# %%
img = '/content/Guitar_1.jpg'
img
# Out:
# '/content/Guitar_1.jpg'

# %%
img = '/content/Guitar_1.jpg'
img = tf.keras.preprocessing.image.load_img(img, target_size=(224, 224))
x = tf.keras.preprocessing.image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

capa = 'block1_pool'
layer = model.get_layer(capa)

partial_model = tf.keras.Model(inputs=model.input, outputs=layer.output)

activations = partial_model.predict(x)

output = partial_model.predict(x)

plt.imshow(output[0, :, :, 0], cmap='viridis')
plt.axis('off')
plt.title(f'Resultado de la capa {capa}')
plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 27ms/step

# %% [markdown]
# #Punto 4

# %%
def conv(imagen, filtro, padding=None, stride=1):
    altura, ancho, canales = imagen.shape
    filtro_altura, filtro_ancho = filtro.shape

    if padding is None:
        padding = 0

    # Calcula las dimensiones de la imagen de salida
    nueva_altura = (altura - filtro_altura + 2 * padding) // stride + 1
    nueva_ancho = (ancho - filtro_ancho + 2 * padding) // stride + 1

    resultado = np.zeros((nueva_altura, nueva_ancho, canales), dtype=np.float32)

    # Aplica el relleno si es necesario
    if padding > 0:
        imagen_rellenada = np.pad(imagen, ((padding, padding), (padding, padding), (0, 0)), mode='constant')
    else:
        imagen_rellenada = imagen

    # Realiza la convolución con el filtro y los parámetros de padding y stride
    for c in range(canales):
        for i in range(0, nueva_altura):
            for j in range(0, nueva_ancho):
                i_inicio = i * stride
                i_fin = i_inicio + filtro_altura
                j_inicio = j * stride
                j_fin = j_inicio + filtro_ancho

                ventana = imagen_rellenada[i_inicio:i_fin, j_inicio:j_fin, c]
                valor = np.sum(ventana * filtro)
                resultado[i, j, c] = valor

    # Escala los valores al rango 0-255
    min_valor = resultado.min()
    max_valor = resultado.max()
    resultado = (resultado - min_valor) / (max_valor - min_valor) * 255

    # Convierte la matriz resultante a tipo uint8
    resultado = resultado.astype(np.uint8)

    return resultado

# %%
weights_layer2 = model.layers[2].get_weights()[0]
filtro_0 = weights_layer2[:, :, :, 0]

# %%
imagen = keras.utils.load_img("/content/Guitar_1.jpg", target_size=(224, 224), keep_aspect_ratio=True)
imagen = keras.utils.img_to_array(imagen)
imagen = preprocess_input(imagen)

plt.imshow(imagen,cmap='viridis')
plt.axis('off')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (-0.5, 223.5, 223.5, -0.5)

# %%
filtro_0[:,:,0]
# Out:
# array([[ 0.16621928,  0.212008  , -0.00591699],
#        [ 0.19920252, -0.02594107, -0.09849164],
#        [-0.01115857, -0.10211428,  0.02734016]], dtype=float32)

# %%
imagen = conv(imagen, filtro_0[:,:,0])
plt.imshow(imagen, cmap='viridis')
